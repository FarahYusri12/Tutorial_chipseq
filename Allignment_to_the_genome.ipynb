# %% [markdown]
# <a href="https://colab.research.google.com/github/FarahYusri12/Tutorial_Reproduce_Genomic_paper_Figures/blob/main/Allignment_to_the_genome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir genome  #make new folder
# %cd genome
# !pwd
# Out:
# /content/genome
# /content/genome

# %%
# !apt-get update
# !apt-get install  -y bowtie2  #install bowtie2
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,201 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,842 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,510 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,286 kB]
# Get:17 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,571 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,901 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,081 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,598 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,281 kB]
# Fetched 37.8 MB in 4s (9,573 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   bowtie2-examples
# The following NEW packages will be installed:
#   bowtie2
# 0 upgraded, 1 newly installed, 0 to remove and 66 not upgraded.
# Need to get 1,169 kB of archives.
# After this operation, 3,735 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 bowtie2 amd64 2.4.4-1 [1,169 kB]
# Fetched 1,169 kB in 1s (875 kB/s)
# Selecting previously unselected package bowtie2.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../bowtie2_2.4.4-1_amd64.deb ...
# Unpacking bowtie2 (2.4.4-1) ...
# Setting up bowtie2 (2.4.4-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !wget https://genome-idx.s3.amazonaws.com/bt/GRCh38_noalt_as.zip
#download pre-build index for bowtie2
# Out:
# --2025-12-08 06:32:19--  https://genome-idx.s3.amazonaws.com/bt/GRCh38_noalt_as.zip
# Resolving genome-idx.s3.amazonaws.com (genome-idx.s3.amazonaws.com)... 54.231.228.201, 16.15.185.112, 3.5.30.209, ...
# Connecting to genome-idx.s3.amazonaws.com (genome-idx.s3.amazonaws.com)|54.231.228.201|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3749239215 (3.5G) [application/zip]
# Saving to: ‘GRCh38_noalt_as.zip’
#
# GRCh38_noalt_as.zip 100%[===================>]   3.49G  41.3MB/s    in 92s
#
# 2025-12-08 06:33:51 (39.0 MB/s) - ‘GRCh38_noalt_as.zip’ saved [3749239215/3749239215]

# %%
# !unzip GRCh38_noalt_as.zip
# Out:
# Archive:  GRCh38_noalt_as.zip
#    creating: GRCh38_noalt_as/
#   inflating: GRCh38_noalt_as/GRCh38_noalt_as.3.bt2
#   inflating: GRCh38_noalt_as/GRCh38_noalt_as.rev.2.bt2
#   inflating: GRCh38_noalt_as/GRCh38_noalt_as.rev.1.bt2
#   inflating: GRCh38_noalt_as/GRCh38_noalt_as.1.bt2
#   inflating: GRCh38_noalt_as/GRCh38_noalt_as.2.bt2
#   inflating: GRCh38_noalt_as/GRCh38_noalt_as.4.bt2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/genome /content/drive/MyDrive/portfolio
